# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Combined.csv')
df
# Out:
#           DEPTH    LCAL        GR    RHOM    APLU  Four_RT   Two_RT   One_RT  \
# 0     4242.9684  8.5405  143.0950  2.7511  0.1276  0.77864  0.77152  0.76816
# 1     4242.8160  8.5412  102.6287  2.6434  0.1081  0.78184  0.77585  0.77438
# 2     4242.6636  8.5606   62.5591  2.5636  0.0871  0.78522  0.78040  0.78152
# 3     4242.5112  8.5651   32.6639  2.5171  0.0773  0.78873  0.78500  0.78915
# 4     4242.3588  8.5860   23.8036  2.5064  0.0771  0.79231  0.78947  0.79661
# ...         ...     ...       ...     ...     ...      ...      ...      ...
# 1100  4075.3284  8.8483   73.2543  2.5791  0.1216  0.76089  0.75711  0.75288
# 1101  4075.1760  8.8479   62.8012  2.5446  0.1195  0.76129  0.75861  0.75637
# 1102  4075.0236  8.8767   42.7415  2.5154  0.0999  0.76173  0.76032  0.76013
# 1103  4074.8712  8.8756   38.4825  2.4958  0.0824  0.76218  0.76209  0.76373
# 1104  4074.7188  8.8275   49.4825  2.5563  0.0791  0.76261  0.76378  0.76678
#
#       Four_RX   Two_RX   One_RX     DTCO      DTSH
# 0     0.79412  0.79461  0.78922  65.8937  104.4344
# 1     0.79697  0.79834  0.79411  66.0644  105.6775
# 2     0.80007  0.80234  0.79987  65.4293  104.6524
# 3     0.80336  0.80645  0.80620  65.8046  105.0880
# 4     0.80680  0.81050  0.81258  65.6507  107.0676
# ...       ...      ...      ...      ...       ...
# 1100  0.78486  0.78449  0.77981  63.9491  107.0481
# 1101  0.78600  0.78641  0.78367  64.5666  108.2560
# 1102  0.78720  0.78850  0.78778  65.3963  113.1766
# 1103  0.78841  0.79060  0.79167  66.5163  118.0417
# 1104  0.78957  0.79255  0.79496  66.5296  126.2994
#
# [1105 rows x 13 columns]

# %%
df.describe()
# Out:
#              DEPTH         LCAL           GR         RHOM         APLU  \
# count  1105.000000  1105.000000  1105.000000  1105.000000  1105.000000
# mean   4158.843600     9.085001    44.908459     2.513996     0.096779
# std      48.635462     0.923961    36.029336     0.096942     0.046277
# min    4074.718800     8.317700    16.434700     1.863900     0.055700
# 25%    4116.781200     8.567600    25.003800     2.482400     0.070400
# 50%    4158.843600     8.773600    29.739500     2.511800     0.084100
# 75%    4200.906000     9.153400    46.498000     2.540300     0.103900
# max    4242.968400    14.100000   195.963900     2.828600     0.484100
#
#            Four_RT       Two_RT       One_RT      Four_RX       Two_RX  \
# count  1105.000000  1105.000000  1105.000000  1105.000000  1105.000000
# mean      0.842065     0.835457     0.832239     0.867301     0.869853
# std       0.115077     0.095151     0.094222     0.131679     0.136502
# min       0.735090     0.725980     0.709740     0.754000     0.752760
# 25%       0.789090     0.789310     0.785380     0.810750     0.811710
# 50%       0.818370     0.819050     0.813520     0.841890     0.844030
# 75%       0.843240     0.843090     0.845420     0.867960     0.872700
# max       1.400370     1.347860     1.361120     1.681020     1.750450
#
#             One_RX         DTCO         DTSH
# count  1105.000000  1105.000000  1105.000000
# mean      0.869137    67.412724   110.813726
# std       0.144028     2.585622    10.042895
# min       0.747760    58.920900    88.883900
# 25%       0.809330    65.824500   104.603800
# 50%       0.838800    66.778700   108.566300
# 75%       0.873110    68.508500   114.332800
# max       1.885400    77.328600   164.396900

# %%
df.isnull().sum()
# Out:
# DEPTH      0
# LCAL       0
# GR         0
# RHOM       0
# APLU       0
# Four_RT    0
# Two_RT     0
# One_RT     0
# Four_RX    0
# Two_RX     0
# One_RX     0
# DTCO       0
# DTSH       0
# dtype: int64

# %%
def plot_graphs(df):
    fig,ax = plt.subplots(nrows=2,ncols=6,figsize=(12,12))
    color_lst = ['r','g','b','y','m']
    bit_size = 8.5
    
    idx  =int(0)
    for i in range(2):
        for j in range(6):
            if i == 0 and j==0:
                ax[i][j].plot(df[df.columns[(idx+1)%(len(df.columns))]],df['DEPTH'],color = color_lst[idx%len(color_lst)],linewidth = 1.5)
                ax[i][j].axvline(bit_size)
                    
            ax[i][j].plot(df[df.columns[(idx+1)%(len(df.columns))]],df['DEPTH'],color = color_lst[idx%len(color_lst)],linewidth = 1.5)
            ax[i][j].grid()
            ax[i][j].invert_yaxis()
            ax[i][j].set_title(df.columns[(idx+1)%(len(df.columns))])
            if i!=0:
                ax[i][j].set_yticklabels([])
            idx +=1

# %%
plot_graphs(df)

# %%
def plot_hist(df):
    color_lst = ['r','g','b','y','m']
    fig,ax = plt.subplots(nrows=2,ncols=6,figsize=(12,6))
    idx  =int(0)
    for i in range(2):
        for j in range(6):
            sns.histplot(df[df.columns[(idx+1)%(len(df.columns))]],kde =True, ax = ax[i][j],color=color_lst[idx%len(color_lst)])
        
            idx += 1

# %%
plot_hist(df)

# %%
grid = sns.PairGrid(df, vars=['DEPTH','GR','RHOM','APLU','One_RT','One_RX'] )
grid.map_diag(plt.hist, edgecolor='w')
grid.map_offdiag(plt.scatter, color='c', edgecolor='w',linewidth=0.1)

# %%
bit_size = 8.5

plt.figure(figsize = (4,10))
plt.plot(df['LCAL'],df['DEPTH'])
# plt.plot(8.5*np.ones(df.shape[0]),df['DEPTH'])
plt.axvline(x = bit_size, color = 'orange' , linewidth = 1)
plt.axvline(x = bit_size + 2 ,color = 'orange',linewidth = 1)


bad_hole_flag = np.where((df['LCAL'] - bit_size)>2,df['DEPTH'],np.nan)

for i in range(len(bad_hole_flag)):
    plt.axhline(y = bad_hole_flag[i],color = 'c',linewidth = 0.2)
    
plt.ylabel('Depth')
plt.title('Borehole Flag')
ax = plt.gca()
ax.invert_yaxis()

# %%
logs = ['LCAL','GR','RHOM','APLU','Four_RT','Four_RX','DTCO','DTSH']
color_lst = ['r','g','b','y','m']

log_idx = int(0)
color_idx = int(0)

fig , ax = plt.subplots(nrows= 2,ncols= 4,figsize = (10,10))

for i in range(2):
    for j in range(4):
        ax[i][j].plot(df[logs[log_idx]],df["DEPTH"],color = color_lst[color_idx%len(color_lst)],linewidth = 1)
        ax[i][j].set_title(logs[log_idx])
        for k in range(len(bad_hole_flag)):
            ax[i][j].axhline(y = bad_hole_flag[k],color = 'c',linewidth = 0.1)
            
        log_idx += 1
        color_idx += 1
        
ax[0][0].set_ylabel('Depth (m)')
# Out:
# Text(0, 0.5, 'Depth (m)')

# %%
# Total porosity

depth = df['DEPTH']
sand_por = (df['APLU'] + 0.04).to_numpy()

sand_por_per = sand_por

fig, ax = plt.subplots(nrows=1,ncols=3,figsize = (10,8))

ax11 = ax[0].twiny()
ax[0].invert_yaxis()
# ax11.invert_yaxis()
ax11.grid(True)
# ax21.set_xlim(140,40)
ax11.spines['top'].set_position(('outward', 0))
ax11.plot(df['RHOM'], depth, '-b', linewidth = 0.8)
ax11.set_xlabel('Bulk Density', color= 'b')
ax11.tick_params(axis='x', colors= 'b')


ax12 = ax[0].twiny()
# ax22.set_xlim(0, 60)
# ax12.invert_yaxis()
ax12.invert_xaxis()
ax12.spines['top'].set_position(('outward', 40))
ax12.plot(sand_por_per, depth, '--k',linewidth = 1)
ax12.set_xlabel('NPHI', color = 'k')
ax12.tick_params(axis= 'x', colors='k')


ax21 = ax[1].twiny()
ax[1].invert_yaxis()
# ax21.invert_yaxis()
ax21.grid(True)
# ax21.set_xlim(140,40)
ax21.spines['top'].set_position(('outward', 0))
ax21.plot(np.log10(df['Four_RT']), depth, '-b', linewidth = 0.8)
ax21.set_xlabel('Four Foot RT', color= 'b')
ax21.tick_params(axis='x', colors= 'b')


ax22 = ax[1].twiny()
# ax22.set_xlim(0, 60)
# ax22.invert_xaxis()
# ax22.invert_yaxis()
ax22.spines['top'].set_position(('outward', 40))
ax22.plot(np.log10(df['Four_RX']), depth, '--k',linewidth = 1)
ax22.set_xlabel('Four Foot RX', color = 'k')
ax22.tick_params(axis= 'x', colors='k')



ax31 = ax[2].twiny()
ax[2].invert_yaxis()
# ax31.invert_yaxis()
ax31.grid(True)
# ax21.set_xlim(140,40)
ax31.spines['top'].set_position(('outward', 0))
ax31.plot(df['GR'], depth, '-b', linewidth = 0.8)
ax31.set_xlabel('GR', color= 'b')
ax31.tick_params(axis='x', colors= 'b')


ax32 = ax[2].twiny()
# ax22.set_xlim(0, 60)
# ax22.invert_xaxis()
ax32.spines['top'].set_position(('outward', 40))
ax32.plot(df['LCAL'], depth, '--k',linewidth = 1)
ax32.set_xlabel('Calliper', color = 'k')
ax32.tick_params(axis= 'x', colors='k')

# %%
td = 4074.5
bd = 4150.5

depth = df['DEPTH'].to_numpy()[np.where(np.logical_and(df['DEPTH'].to_numpy()>=td,df['DEPTH'].to_numpy()<=bd))]
bulk_den = df['RHOM'].to_numpy()[np.where(np.logical_and(df['DEPTH'].to_numpy()>=td,df['DEPTH'].to_numpy()<=bd))]

por_d = (2.65-bulk_den)/(2.65 - 1.1)
por_n = (df['APLU'] + 0.04).to_numpy()[np.where(np.logical_and(df['DEPTH'].to_numpy()>=td,df['DEPTH'].to_numpy()<=bd))]

por_gas = ((por_d**2 + por_n**2)/2)**(0.5)

# %%
por_gas.mean()
# Out:
# 0.14076926730431635

# %%
por_d_total = (2.65-df['RHOM'])/(2.65 - 1.1)

plt.figure(figsize = (4,10))
plt.plot(por_d_total,df['DEPTH'])
plt.plot(df['APLU'] +0.04, df['DEPTH'])
ax = plt.gca()
ax.invert_yaxis()

# %%
td = 4074.5
bd = 4150.5

depth = df['DEPTH'].to_numpy()[np.where(np.logical_and(df['DEPTH'].to_numpy()>=td,df['DEPTH'].to_numpy()<=bd))]
bulk_den = df['RHOM'].to_numpy()[np.where(np.logical_and(df['DEPTH'].to_numpy()>=td,df['DEPTH'].to_numpy()<=bd))]

por_d_temp = (2.65-bulk_den)/(2.65 - 1.1)
por_n_temp  = (df['APLU'] + 0.04).to_numpy()[np.where(np.logical_and(df['DEPTH'].to_numpy()>=td,df['DEPTH'].to_numpy()<=bd))]

por_temp_oil_water = (por_d_temp+por_n_temp)/2

# %%
td = 4150.5
bd = 4243

depth = df['DEPTH'].to_numpy()[np.where(np.logical_and(df['DEPTH'].to_numpy()>=td,df['DEPTH'].to_numpy()<=bd))]
bulk_den = df['RHOM'].to_numpy()[np.where(np.logical_and(df['DEPTH'].to_numpy()>=td,df['DEPTH'].to_numpy()<=bd))]

por_d_temp = (2.65-bulk_den)/(2.65 - 1.1)
por_n_temp = (df['APLU'] + 0.04).to_numpy()[np.where(np.logical_and(df['DEPTH'].to_numpy()>=td,df['DEPTH'].to_numpy()<=bd))]

por_temp_gas =((por_d_temp**2 + por_n_temp**2)/2)**(0.5)

# %%
temp_merged = np.concatenate((por_temp_oil_water,por_temp_gas))
print(temp_merged.shape)
# Out:
# (1105,)

# %%
Rw = 0.1
temp_Sw = (Rw/(((temp_merged)**2)*df['Four_RT'] ))**0.5

# %%
t1 = pd.Series(temp_Sw)
# print(t1)
print(t1.min())
print(t1.max())
# Out:
# 0.6811922227424391
# 13.652745295292833

# %%
temp_1 = np.where(temp_Sw >= 1 ,1,temp_Sw)

plt.figure(figsize = (4,10))
plt.plot(temp_1,df["DEPTH"])
ax = plt.gca()
ax.invert_yaxis()

# %%
td = 4150.5
bd = 4243

depth = df['DEPTH'].to_numpy()[np.where(np.logical_and(df['DEPTH'].to_numpy()>=td,df['DEPTH'].to_numpy()<=bd))]
bulk_den = df['RHOM'].to_numpy()[np.where(np.logical_and(df['DEPTH'].to_numpy()>=td,df['DEPTH'].to_numpy()<=bd))]

por_d = (2.65-bulk_den)/(2.65 - 1.1)
por_n = (df['APLU'] + 0.04).to_numpy()[np.where(np.logical_and(df['DEPTH'].to_numpy()>=td,df['DEPTH'].to_numpy()<=bd))]
Rw = 0.1
por_oil_water = (por_d + por_n)/2

merged_por = np.concatenate((por_gas,por_oil_water))

Sw = (Rw/(((merged_por)**2)*df['Four_RT'] ))**0.5

Sw_new = np.where(Sw>1,1,Sw)

plt.figure(figsize = (4,10))
plt.plot(Sw_new,df['DEPTH'])
plt.ylabel('Depth')
plt.title('Water Saturation Sw')
ax = plt.gca()
ax.invert_yaxis()
plt.grid()

# %%
Sw_new = pd.Series(Sw_new)
Sw_new.value_counts()
# Out:
# 1.000000    1100
# 0.855540       1
# 0.713485       1
# 0.681192       1
# 0.720190       1
# 0.937919       1
# dtype: int64

# %% [markdown]
# ### Volume of Shale

# %%
GR = df['GR'].to_numpy()

GR_min = np.percentile(GR,5)
GR_max = np.percentile(GR,95)

IGR = (GR - GR_min)/(GR_max - GR_min)

# Vsh = 0.33*(2**(2*IGR) - 1)
Vsh = IGR

plt.figure(figsize = (4,8))
plt.plot(df['GR'],df['DEPTH'],label = 'GR')
plt.plot(np.ones(len(GR))*GR_min,df['DEPTH'],label = 'Sand line')
plt.plot(np.ones(len(GR))*GR_max,df['DEPTH'],label = 'Shale line')
plt.legend(loc='upper right')
plt.xlabel('GR')
plt.ylabel('Depth')
# Out:
# Text(0, 0.5, 'Depth')

# %%
df['GR'].plot(kind='hist', bins=40, density=True,edgecolor='black')
df['GR'].plot(kind='kde',color='black')
plt.xlabel('GR[API]', fontsize=14)
mean=df['GR'].mean()
p05=df.GR.quantile(0.05)
p95=df.GR.quantile(0.95)
plt.axvline(mean,color='g',label='mean')
plt.axvline(p05,color='r',label='p5')
plt.axvline(p95,color='y',label='p95')
plt.legend()
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %%
flag = np.zeros(df.shape[0])
depth = df['DEPTH'].to_numpy()

plt.figure(figsize = (4,10))
for i in range(len(Vsh)):
    if Vsh[i] <= 0.4 and Sw[i] <= 0.7:
        flag[i] = 1

    
for i in range(len(flag)):
    if flag[i] == 1:
        plt.axhline(y = depth[i],linewidth = 1)
 
plt.ylim(4074,4242)
plt.title('Reservoir flag')
plt.grid()
ax = plt.gca()
ax.invert_yaxis()

# %%
plt.figure(figsize = (4,8))
plt.plot(Vsh,df['DEPTH'])
plt.title('Vsh')
plt.ylabel('Depth')
ax = plt.gca()
ax.invert_yaxis()
plt.grid()

# %% [markdown]
# ### Sonic

# %%
# td =4074.5
# bd = 4242.9

# depth  = df_4['DEPTH'].to_numpy()[np.where(np.logical_and(df_4['DEPTH'].to_numpy()>=td,df_4['DEPTH'].to_numpy()<=bd))]
depth =  df['DEPTH']

# vp=df['DTCO'].to_numpy()[np.where(np.logical_and(df['DEPTH'].to_numpy()>=td,df['DEPTH'].to_numpy()<=bd))]
# vs=df['DTSH'].to_numpy()[np.where(np.logical_and(df['DEPTH'].to_numpy()>=td,df['DEPTH'].to_numpy()<=bd))]

vp = df['DTCO']
vs = df['DTSH']

por=(df['APLU'] + 0.04).to_numpy()[np.where(np.logical_and(df['DEPTH'].to_numpy()>=td,df['DEPTH'].to_numpy()<=bd))]
plt.figure(figsize=(3,10))

vp_corrected=304800/vp
vs_corrected=304800/vs

fig,ax = plt.subplots(nrows=1,ncols=2,figsize = (10,7))

t1 = ax[0].scatter(vp_corrected,depth,c = Vsh,marker = 'o',s=20,label = 'Vp',cmap = 'jet')
plt.colorbar(t1)
ax[0].set_ylabel('Depth')
ax[0].set_title('Vp (m/s)')
ax[0].invert_yaxis()
ax[0].grid()

t2 = ax[1].scatter(vs_corrected,depth,c = Vsh,marker = 'o',s=20,label = 'Vs',cmap = 'jet')
plt.colorbar(t2,label = 'Vsh')
ax[1].set_title('Vs (m/s)')
ax[1].invert_yaxis()
ax[1].grid()



# plt.legend(loc = 'upper center')

# %%
fig,ax = plt.subplots(nrows=1,ncols=2,figsize = (10,7))

t1 = ax[0].scatter(vp_corrected,depth,c =merged_por,marker = 'o',s=20,label = 'Vp',cmap = 'jet')
plt.colorbar(t1)
ax[0].set_ylabel('Depth')
ax[0].set_title('Vp (m/s)')
ax[0].invert_yaxis()
ax[0].grid()

t2 = ax[1].scatter(vs_corrected,depth,c = merged_por,marker = 'o',s=20,label = 'Vs',cmap = 'jet')
plt.colorbar(t2,label = 'Porosity')
ax[1].set_title('Vs (m/s)')
ax[1].invert_yaxis()
ax[1].grid()

# %% [markdown]
# ### Total porosity plot

# %%
plt.figure(figsize = (3,10))

fig , ax = plt.subplots(1,2,figsize = (6,10))
ax[0].plot(merged_por,df['DEPTH'])
ax[1].plot(df['GR'],df['DEPTH'])

ax[0].invert_yaxis()
ax[1].invert_yaxis()

ax[0].set_title('Porosity')
ax[1].set_title('GR')

ax[0].grid()
ax[1].grid()
# plt.title('Porosity')
# plt.ylabel('Depth')

print(merged_por.max())
print(merged_por.mean())
# Out:
# 0.5074807456454211
# 0.11817127276730509
